# %%
#importing necessary libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#extracting the dataset
df = pd.read_csv('winequality-red.csv')

# %%
# Displaying the total rows of each column and datatype of columns
df.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]>

# %%
#describing the dataframe
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
#display the correlation between variables
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
# display no. of rows and columns
df.shape
# Out:
# (1599, 12)

# %%
# check for missing data
df.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
#visualization of target 
sns.countplot(x = 'quality', data = df)
plt.xlabel('Quality')
plt.ylabel('Count')
plt.title('Count of each target', size = 20)
# Out:
# Text(0.5, 1.0, 'Count of each target')

# %%
#seperating feature and target attribute
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
#splitting the data 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

print("Length of X_train : ", len(X_train))
print("Length of X_test  : ", len(X_test))
print("Length of y_train : ", len(y_train))
print("Length of y_test  : ", len(y_test))
# Out:
# Length of X_train :  1279
# Length of X_test  :  320
# Length of y_train :  1279
# Length of y_test  :  320

# %%
#preprocessing the data
from sklearn.preprocessing import StandardScaler

x_sc = StandardScaler()
y_sc = StandardScaler()

train_data = y_train.reshape(len(y_train), 1)
test_data = y_test.reshape(len(y_test), 1)

X_std_train = x_sc.fit_transform(train_data)
y_std_train = y_sc.fit_transform(train_data)

X_std_test = x_sc.transform(test_data)
y_std_test = y_sc.transform(test_data)

# %%
#loading necessary libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

# %%
#fit transforming the data to models
dtc = DecisionTreeClassifier().fit(X_train, y_train)
rfc = RandomForestClassifier(n_estimators=100).fit(X_train, y_train)
knc = KNeighborsClassifier().fit(X_train, y_train)
lor = LogisticRegression().fit(X_train, y_train)
lr = LinearRegression().fit(X_train, y_train)
# Out:
# C:\Users\swtsa\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#predicting the models
dtc_pred = dtc.predict(X_test)
rfc_pred = rfc.predict(X_test)
knc_pred = knc.predict(X_test)
lor_pred = lor.predict(X_test)
lr_pred = lr.predict(X_test)

# %%
#importing necessary libraries
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score, mean_squared_error

# %%
#displaying accuracy of models
print(f"Accuracy of Decision tree Classifier \t {round(accuracy_score(dtc_pred, y_test) * 100, 2)}%")
print(f"Accuracy of Random Forest Classifier \t {round(accuracy_score(rfc_pred, y_test) * 100, 2)}%")
print(f"Accuracy of K Neighbors Classifier   \t {round(accuracy_score(knc_pred, y_test) * 100, 2)}%")
print(f"Accuracy of Logistic regression      \t {round(accuracy_score(lor_pred, y_test) * 100, 2)}%")
# Out:
# Accuracy of Decision tree Classifier 	 63.44%
# Accuracy of Random Forest Classifier 	 72.5%
# Accuracy of K Neighbors Classifier   	 49.06%
# Accuracy of Logistic regression      	 58.75%

# %%
#displaying r2 score and mse for linear regression
print(f"r2_score of Linear Regressor         \t {r2_score(y_test, lr_pred)}")
print(f"mean_squared_error of Linear Regressor         \t {np.sqrt(mean_squared_error(y_test, lr_pred))}")
# Out:
# r2_score of Linear Regressor         	 0.3825099534074472
# mean_squared_error of Linear Regressor         	 0.6235396082117022

# %%
# WINE QUALITY IS GOOD
